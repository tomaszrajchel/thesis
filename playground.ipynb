# %%
import pandas as pd
import numpy as np
df = pd.read_csv("input/training.csv")
df.head()
# Out:
#    Unnamed: 0  DeltaR_lab23  DeltaR_lab45 Label  lab0_ENDVERTEX_CHI2  \
# 0        8492      1.653351      0.641569     b             0.961874
# 1          96      2.227934      0.332075     b             4.795827
# 2         680      2.819223      0.499507     b             2.371008
# 3        8848      2.016268      0.670289     b            11.221996
# 4        6618      2.875873      0.479683     b             1.927824
#
#    lab0_IPCHI2_OWNPV  lab0_RFD  lab0_ptasy_1.50  lab10_IPCHI2_OWNPV  \
# 0          16.007687  0.938971        -0.244488          131.797550
# 1          13.944221  0.639592        -0.374541            4.615454
# 2          19.803263  0.326038        -0.386808          560.866547
# 3           3.265808  1.876633        -0.400453           23.337155
# 4          15.222369  0.197828        -0.638294           16.085697
#
#    lab2_FDCHI2_OWNPV  lab2_IPCHI2_OWNPV      lab2_PT  lab4_ENDVERTEX_CHI2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8470 entries, 0 to 8469
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           8470 non-null   int64
#  1   DeltaR_lab23         8470 non-null   float64
#  2   DeltaR_lab45         8470 non-null   float64
#  3   Label                8470 non-null   object
#  4   lab0_ENDVERTEX_CHI2  8470 non-null   float64
#  5   lab0_IPCHI2_OWNPV    8470 non-null   float64
#  6   lab0_RFD             8470 non-null   float64
#  7   lab0_ptasy_1.50      8470 non-null   float64
#  8   lab10_IPCHI2_OWNPV   8470 non-null   float64
#  9   lab2_FDCHI2_OWNPV    8470 non-null   float64
#  10  lab2_IPCHI2_OWNPV    8470 non-null   float64
#  11  lab2_PT              8470 non-null   float64
#  12  lab4_ENDVERTEX_CHI2  8470 non-null   float64
#  13  lab4_RFD             8470 non-null   float64
#  14  lab5_PT              8470 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  DeltaR_lab23  DeltaR_lab45  lab0_ENDVERTEX_CHI2  \
# count   8470.000000   8470.000000   8470.000000          8470.000000
# mean    4245.157497      1.810193      0.889499             6.706004
# std     3427.932924      1.521709      1.289124             6.086598
# min        0.000000      0.006584      0.004390            -0.870992
# 25%      815.000000      0.491950      0.319659             2.166487
# 50%     3718.000000      1.429810      0.538004             4.664304
# 75%     7253.750000      2.720533      0.829399             9.438129
# max    11016.000000      6.326523      6.338531            29.972523
#
#        lab0_IPCHI2_OWNPV     lab0_RFD  lab0_ptasy_1.50  lab10_IPCHI2_OWNPV  \
# count        8470.000000  8470.000000      8470.000000         8470.000000
# mean            9.133768     1.134324        -0.071313          234.118476
# std             7.500108     0.944295         0.414176          337.524966
# ...

# %%
df.hist(bins=100, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'DeltaR_lab23'}>,
#         <AxesSubplot:title={'center':'DeltaR_lab45'}>,
#         <AxesSubplot:title={'center':'lab0_ENDVERTEX_CHI2'}>],
#        [<AxesSubplot:title={'center':'lab0_IPCHI2_OWNPV'}>,
#         <AxesSubplot:title={'center':'lab0_RFD'}>,
#         <AxesSubplot:title={'center':'lab0_ptasy_1.50'}>,
#         <AxesSubplot:title={'center':'lab10_IPCHI2_OWNPV'}>],
#        [<AxesSubplot:title={'center':'lab2_FDCHI2_OWNPV'}>,
#         <AxesSubplot:title={'center':'lab2_IPCHI2_OWNPV'}>,
#         <AxesSubplot:title={'center':'lab2_PT'}>,
#         <AxesSubplot:title={'center':'lab4_ENDVERTEX_CHI2'}>],
#        [<AxesSubplot:title={'center':'lab4_RFD'}>,
#         <AxesSubplot:title={'center':'lab5_PT'}>,
#         <AxesSubplot:title={'center':'lab8_PT'}>,
#         <AxesSubplot:title={'center':'lab9_IPCHI2_OWNPV'}>]], dtype=object)
